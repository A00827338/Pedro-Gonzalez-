# %% [markdown]
# Data base sales Grupo Everest 2019 - 2022

# %% [markdown]
# Describes the data set. What data does it contain?
#
# The sales of the company for each month, the number of work order, amount purchased, price, name of the company, product , and service included

# %% [markdown]
# What are some of the questions you could answer with this data? List at least FIVE (do not answer the questions)
#
# 1.- Increase in sales for months elapsed
# 2.- The service most profitable
# 3.- Variables which afect the monthly sales
# 4.- Sales seasonality
# 5.- Return of investment by marketing

# %% [markdown]
# Which stakeholder (company, sector of society, decentralized body, government, etc.) would be interested in the questions you identified in point 6?
#
# companies dedicated to the textile sector
