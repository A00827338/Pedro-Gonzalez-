# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("Datosventas4.csv")
df
# Out:
#         ID   Num pedido mes Mes de venta          Cliente  Giro de cliente   \
# 0    220101             1.0        enero               NYC      Transporte
# 1    220102             2.0        enero               NYC      Transporte
# 2    220103             3.0         enero  Transp Urgentes      Transporte
# 3    220104             4.0         enero  Transp Urgentes      Transporte
# 4    220105             5.0         enero         NUEVOMEX      Transporte
# ..      ...             ...           ...              ...              ...
# 921  211265            68.0     diciembre       INTERMODAL       Logistica
# 922  211266            69.0     diciembre       INTERMODAL       Logistica
# 923  211267            70.0     diciembre           Kayak       Industrial
# 924  211268            71.0     diciembre           LAMSER      Industrial
# 925  211269            72.0     diciembre           LAMSER      Industrial
#
# ...

# %%
df.describe()
# Out:
#                 ID   Num pedido mes     Volumen        Pago
# count  9.260000e+02      914.000000   922.000000  900.000000
# mean   2.428300e+05       35.851204    47.470716    0.972222
# std    2.398852e+05       23.793327    87.511859    0.236553
# min    2.101010e+05        1.000000     0.000000    0.000000
# 25%    2.104582e+05       16.250000    12.000000    1.000000
# 50%    2.108265e+05       33.000000    24.000000    1.000000
# 75%    2.111818e+05       52.000000    51.000000    1.000000
# max    2.111114e+06      119.000000  1640.000000    2.000000

# %%
x = df.columns.tolist()
x.sort()
x
# Out:
# ['Cliente ',
#  'Concepto ',
#  'Costo total ',
#  'Costo unitario ',
#  'Giro de cliente ',
#  'ID ',
#  'Ingreso',
#  'Mes de venta ',
#  'Num pedido mes',
#  'Pago ',
#  'Precio de venta ',
#  'Servicio ',
#  'Utilidad ',
#  'Vendedor ',
#  'Venta total ',
#  'Volumen ']

# %%
pd.pivot_table(df,
               index = "Cliete", 
               aggfunc = 'median', #funciones como en excel
               values = "Ingreso", #Solo imprime los valores que queremos 
               margins = True,
               columns = "Giro de cliente" #sumlev es una columna, no es una formula
              )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [28], in <module>
# ----> 1 pd.pivot_table(df,
#       2                index = "Cliete",
#       3                aggfunc = 'median', #funciones como en excel
#       4                values = "Ingreso", #Solo imprime los valores que queremos
#       5                margins = True,
#       6                columns = "Giro de cliente" #sumlev es una columna, no es una formula
#       7               )
#
# File /srv/conda/envs/notebook/lib/python3.8/site-packages/pandas/core/reshape/pivot.py:100, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#      97             pass
#      98     values = list(values)
# --> 100 grouped = data.groupby(keys, observed=observed)
#     101 agged = grouped.agg(aggfunc)
# ...
